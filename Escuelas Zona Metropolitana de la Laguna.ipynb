# %%
import numpy as np

# %%
import pandas as pd

# %%
coah = pd.read_csv('cct05.csv')

# %%
dgo = pd.read_csv('cct10.csv')

# %%
coah.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5158 entries, 0 to 5157
# Data columns (total 32 columns):
# clavecct          5158 non-null object
# nombrecct         5158 non-null object
# domicilio         5158 non-null object
# numext            922 non-null object
# entrecalle        3769 non-null object
# ycalle            3671 non-null object
# callepost         0 non-null float64
# codpost           4601 non-null float64
# colonia           0 non-null float64
# ncolonia          0 non-null float64
# localidad         5158 non-null int64
# municipio         5158 non-null int64
# entidad           5158 non-null int64
# ambito            5158 non-null object
# longitud          5158 non-null float64
# latitud           5158 non-null float64
# turno             5158 non-null int64
# nturno            5158 non-null object
# tipo              5158 non-null int64
# ntipo             5158 non-null object
# nivel             5158 non-null int64
# ...

# %%
dgo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5950 entries, 0 to 5949
# Data columns (total 32 columns):
# clavecct          5950 non-null object
# nombrecct         5950 non-null object
# domicilio         5950 non-null object
# numext            1571 non-null object
# entrecalle        823 non-null object
# ycalle            636 non-null object
# callepost         45 non-null object
# codpost           5946 non-null float64
# colonia           1322 non-null float64
# ncolonia          1322 non-null object
# localidad         5950 non-null int64
# municipio         5950 non-null int64
# entidad           5950 non-null int64
# ambito            5950 non-null object
# longitud          5950 non-null float64
# latitud           5950 non-null float64
# turno             5950 non-null int64
# nturno            5950 non-null object
# tipo              5950 non-null int64
# ntipo             5950 non-null object
# nivel             5950 non-null int64
# ...

# %%
torMat = coah[(coah['municipio'] == 35) | (coah['municipio'] == 17)]

# %%
gpLer = dgo[(dgo['municipio'] == 5) | (dgo['municipio'] == 12)]

# %%
torMat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1275 entries, 0 to 5156
# Data columns (total 32 columns):
# clavecct          1275 non-null object
# nombrecct         1275 non-null object
# domicilio         1275 non-null object
# numext            317 non-null object
# entrecalle        1056 non-null object
# ycalle            1032 non-null object
# callepost         0 non-null float64
# codpost           1219 non-null float64
# colonia           0 non-null float64
# ncolonia          0 non-null float64
# localidad         1275 non-null int64
# municipio         1275 non-null int64
# entidad           1275 non-null int64
# ambito            1275 non-null object
# longitud          1275 non-null float64
# latitud           1275 non-null float64
# turno             1275 non-null int64
# nturno            1275 non-null object
# tipo              1275 non-null int64
# ntipo             1275 non-null object
# nivel             1275 non-null int64
# ...

# %%
gpLer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1387 entries, 0 to 5949
# Data columns (total 32 columns):
# clavecct          1387 non-null object
# nombrecct         1387 non-null object
# domicilio         1387 non-null object
# numext            634 non-null object
# entrecalle        444 non-null object
# ycalle            367 non-null object
# callepost         28 non-null object
# codpost           1386 non-null float64
# colonia           769 non-null float64
# ncolonia          769 non-null object
# localidad         1387 non-null int64
# municipio         1387 non-null int64
# entidad           1387 non-null int64
# ambito            1387 non-null object
# longitud          1387 non-null float64
# latitud           1387 non-null float64
# turno             1387 non-null int64
# nturno            1387 non-null object
# tipo              1387 non-null int64
# ntipo             1387 non-null object
# nivel             1387 non-null int64
# ...

# %%
zmLag = pd.concat([torMat,gpLer])

# %%
zmLag.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2662 entries, 0 to 5949
# Data columns (total 32 columns):
# clavecct          2662 non-null object
# nombrecct         2662 non-null object
# domicilio         2662 non-null object
# numext            951 non-null object
# entrecalle        1500 non-null object
# ycalle            1399 non-null object
# callepost         28 non-null object
# codpost           2605 non-null float64
# colonia           769 non-null float64
# ncolonia          769 non-null object
# localidad         2662 non-null int64
# municipio         2662 non-null int64
# entidad           2662 non-null int64
# ambito            2662 non-null object
# longitud          2662 non-null float64
# latitud           2662 non-null float64
# turno             2662 non-null int64
# nturno            2662 non-null object
# tipo              2662 non-null int64
# ntipo             2662 non-null object
# nivel             2662 non-null int64
# ...

# %%
zmLag.groupby('ntipo').count()
# Out:
#                           clavecct  nombrecct  domicilio  numext  entrecalle  \
# ntipo
# EDUCACION BASICA              2224       2224       2224     808        1143
# EDUCACION ESPECIAL              97         97         97      58          81
# EDUCACION INICIAL               18         18         18       0          18
# EDUCACION MEDIA SUPERIOR       227        227        227      53         180
# EDUCACION SUPERIOR              96         96         96      32          78
#
#                           ycalle  callepost  codpost  colonia  ncolonia  \
# ntipo
# EDUCACION BASICA            1064         17     2172      597       597
# EDUCACION ESPECIAL            80          2       95       45        45
# EDUCACION INICIAL             18          0       18        9         9
# EDUCACION MEDIA SUPERIOR     167          3      224       72        72
# EDUCACION SUPERIOR            70          6       96       46        46
#
# ...

# %%
zmLag.groupby('tipo').count()
# Out:
#       clavecct  nombrecct  domicilio  numext  entrecalle  ycalle  callepost  \
# tipo
# 1         2224       2224       2224     808        1143    1064         17
# 2          227        227        227      53         180     167          3
# 3           96         96         96      32          78      70          6
# 4           18         18         18       0          18      18          0
# 5           97         97         97      58          81      80          2
#
#       codpost  colonia  ncolonia       ...        subnivel  nsubnivel  \
# tipo                                   ...
# 1        2172      597       597       ...            2224       2224
# 2         224       72        72       ...             227        227
# 3          96       46        46       ...              96         96
# 4          18        9         9       ...              18         18
# 5          95       45        45       ...              97         97
#
# ...

# %%
zmLag.groupby('nnivel').count()
# Out:
#                                          clavecct  nombrecct  domicilio  \
# nnivel
# BACHILLERATO                                  199        199        199
# ESPECIAL                                       97         97         97
# NO ESCOLARIZADO                                18         18         18
# PEDAGOGICA, UNIVERSITARIA O TECNOLOGICA        96         96         96
# PREESCOLAR                                    913        913        913
# PRIMARIA                                      965        965        965
# PROFESIONAL                                    28         28         28
# SECUNDARIA                                    346        346        346
#
#                                          numext  entrecalle  ycalle  \
# nnivel
# BACHILLERATO                                 49         153     141
# ESPECIAL                                     58          81      80
# NO ESCOLARIZADO                               0          18      18
# ...

# %%
zmLag.groupby('nsubnivel').count()
# Out:
#                                          clavecct  nombrecct  domicilio  \
# nsubnivel
# BACHILLERATO GENERAL                          160        160        160
# BACHILLERATO TECNOLOGICO                       39         39         39
# CAM                                            19         19         19
# CONALEP                                         4          4          4
# NO ESCOLARIZADO                                18         18         18
# PEDAGOGICA, UNIVERSITARIA O TECNOLOGICA        96         96         96
# PREESCOLAR CENDI                               10         10         10
# PREESCOLAR CONAFE                              92         92         92
# PREESCOLAR GENERAL                            811        811        811
# PRIMARIA CONAFE                                31         31         31
# PRIMARIA GENERAL                              934        934        934
# PROFESIONAL TECNICO                            24         24         24
# ...

# %%
zmLagEs = zmLag[zmLag['tipo'] == 3]

# %%
zmLagEs.to_excel('ZMLagES.xlsx', sheet_name='ZMLagES')
